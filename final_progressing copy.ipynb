# %%
import json
import json
import random
from datetime import datetime
import os
import math

# 定义一个函数来读取 JSON 文件
def read_json_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data



def clean_data_jobName(data):
    # 清洗数据：去除包含“实习”或“intern”的职位
    cleaned_data = [item for item in data if "实习" not in item["jobName"] and "intern" not in item["jobName"].lower()]

    return cleaned_data
    





def transform_salary_description(salary_desc):
    # 检查是否包含"及以下"，以及是千还是万
    if '千及以下' in salary_desc:
        value, _ = salary_desc.split('千及以下')
        min_value = round(float(value) * 0.6, 5)  # 计算下限并四舍五入到5位小数
        new_salary_desc = f"{min_value}-{value}千"
    elif '万及以下' in salary_desc:
        value, _ = salary_desc.split('万及以下')
        min_value = round(float(value) * 0.6, 5)  # 计算下限并四舍五入到5位小数
        new_salary_desc = f"{min_value}-{value}万"
    else:
        # 如果不符合上述任一条件，则不需要转换
        return salary_desc
    
    return new_salary_desc


def parse_and_average_salary(salary):
    # 将薪资字符串中的“千”和“万”统一转换为浮点数（以“万”为单位）
    if "万" in salary:
        salary = salary.replace('千', '*0.1').replace('万', '')
        # 分割薪资范围
        salary_range = salary.split('-')
        # 计算薪资范围的平均值
        if len(salary_range) == 2:
            min_salary, max_salary = salary_range
            average_salary = ((eval(min_salary) + eval(max_salary)) * 10000) / 2
        else:
            average_salary = eval(salary_range[0]) * 10000
        return round(average_salary , 2)  # 返回平均薪资，单位为元
    #仅含"千"
    else:
        salary = salary.replace('千', '')
        salary_range = salary.split('-')
        if len(salary_range) == 2:
            min_salary, max_salary = salary_range
            average_salary = ((eval(min_salary) + eval(max_salary)) * 1000) / 2
        else:
            average_salary = eval(salary_range[0]) * 1000
        return round(average_salary , 2)  # 返回平均薪资，单位为元


def calculate_monthly_salary(salary_string):
    # 假设transform_salary_description已经将薪资描述转换为了易于解析的格式
    salary_string=transform_salary_description(salary_string)
    if '年' in salary_string:
        salary_string = salary_string.replace('/年', '')
        average_annual_salary = parse_and_average_salary(salary_string)
        return round(average_annual_salary / 12, 2)  # 转换为月薪
    elif '薪' in salary_string:
        salary_range, months = salary_string.split('·')
        average_salary = parse_and_average_salary(salary_range)
        months = float(months.replace('薪', ''))
        return round(average_salary * months / 12, 2)  # 计算年薪再转换为月薪
    elif '-' in salary_string:
        return parse_and_average_salary(salary_string)  # 直接返回月薪
    else:
        # 不属于上述情况，可能需要进一步处理
        print(salary_string)
        return None



def random_split_json_array(file_path, num_files=6):
    # 读取原始JSON文件
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)

    # 随机打乱数组
    random.shuffle(data)

    # 计算每份数据的大小
    total_items = len(data)
    items_per_file = math.ceil(total_items / num_files)

    # 获取原始文件所在目录
    original_dir = os.path.dirname(file_path)

    # 分割并保存到新的JSON文件，文件保存在原始文件同目录
    for i in range(num_files):
        start_index = i * items_per_file
        end_index = min(start_index + items_per_file, total_items)
        split_data = data[start_index:end_index]

        # 构造新文件路径
        new_file_path = os.path.join(original_dir, f'random_part_{i+1}.json')

        with open(new_file_path, 'w', encoding='utf-8') as split_file:
            json.dump(split_data, split_file, indent=4, ensure_ascii=False)

# %%
# 替换以下路径为你的实际文件路径
input_file = r'C:\Users\Xue\Documents\GitHub\gender-discrimination-hiring\修正\data_part_all.json'  # 输入文件路径
output_file = r'C:\Users\Xue\OneDrive\0_Code\data\final_processed_jobs.json'  # 输出文件路径

# %%
data=read_json_file(input_file)

# %%
for i in range(1,7):
    for job in data[f'random_part_{i}']:
        if '在校生/应届生' not in job['workYearString']:
            if "应届" in job['jobName'] or "在校" in job['jobName']:
                print(job)
# Out:
# {'jobId': '153565757', 'jobName': '座椅测试工程师（应届毕业生）', 'jobAreaString': '上海', 'provideSalaryString': '4-7千', 'issueDateString': '2024-03-12 23:32:06', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '上海沿浦金属制品股份有限公司', 'companyTypeString': '已上市', 'companySizeString': '150-500人', 'jobHref': 'https://jobs.51job.com/shanghai-mhq/153565757.html?s=sou_sou_soulb&t=0_0&req=6e8579562be21f3f2169f3387c386276', 'termStr': '全职', 'jobWelfareCodeDataList': ['带薪年假', '五险一金', '包住宿', '绩效奖金', '全勤奖', '节日福利'], 'monthly_salary': 5500.0, 'competition': '45'}
# {'jobId': '131220715', 'jobName': '部门助理（双休、可招应届生）', 'jobAreaString': '深圳', 'provideSalaryString': '5-8千', 'issueDateString': '2024-04-01 11:52:39', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '昭星实业（深圳）有限公司', 'companyTypeString': '民营', 'companySizeString': '50-150人', 'jobHref': 'https://jobs.51job.com/shenzhen-gmq/131220715.html?s=sou_sou_soulb&t=0_0&req=a51d7c6820bef931b2a9ff141c8df2d8', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '员工旅游', '绩效奖金', '节日福利', '带薪年假', '周末双休', '全勤奖', '餐饮补贴'], 'monthly_salary': 6500.0, 'competition': '181'}
# {'jobId': '153928590', 'jobName': '本科应届生', 'jobAreaString': '深圳', 'provideSalaryString': '5-7千', 'issueDateString': '2024-03-28 10:15:59', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '深圳市新能安华技术有限公司', 'companyTypeString': '民营', 'companySizeString': '少于50人', 'jobHref': 'https://jobs.51job.com/shenzhen-baq/153928590.html?s=sou_sou_soulb&t=0_0&req=151a3a896b83917b84d220429441aea7', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '餐饮补贴'], 'monthly_salary': 6000.0, 'competition': '329'}
# {'jobId': '152949119', 'jobName': '项目助理（应届）', 'jobAreaString': '上海', 'provideSalaryString': '6-8千·13薪', 'issueDateString': '2024-04-03 09:17:23', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '上海元初国际物流有限公司', 'companyTypeString': '民营', 'companySizeString': '150-500人', 'jobHref': 'https://jobs.51job.com/shanghai-mhq/152949119.html?s=sou_sou_soulb&t=0_0&req=f0bda063b0f55cf9220331b6bc0d7316', 'termStr': '全职', 'jobWelfareCodeDataList': [], 'monthly_salary': 7583.33, 'competition': '167'}
# {'jobId': '153309267', 'jobName': 'C++开发工程师（应届生）', 'jobAreaString': '上海', 'provideSalaryString': '8千-1万·13薪', 'issueDateString': '2024-03-27 17:47:59', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '上海博恩登特科技有限公司', 'companyTypeString': '合资', 'companySizeString': '1000-5000人', 'jobHref': 'https://jobs.51job.com/shanghai-jdq/153309267.html?s=sou_sou_soulb&t=0_0&req=6dfc7b2cf81ae7bae5cebe540082d904', 'termStr': '全职', 'jobWelfareCodeDataList': ['交通补贴', '餐饮补贴', '通讯补贴', '绩效奖金', '年终奖金', '定期体检'], 'monthly_salary': 9750.0, 'competition': '356'}
# {'jobId': '40623618', 'jobName': 'PHP软件开发工程师（应届生亦可）', 'jobAreaString': '上海', 'provideSalaryString': '8千-1万', 'issueDateString': '2024-04-05 11:25:36', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '亿泰和信息技术（上海）有限公司', 'companyTypeString': '外资（欧美）', 'companySizeString': '50-150人', 'jobHref': 'https://jobs.51job.com/shanghai-ptq/40623618.html?s=sou_sou_soulb&t=0_0&req=5020d73e3772c10c0e47b47c470917eb', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '餐饮补贴', '年终奖金', '专业培训'], 'monthly_salary': 9000.0, 'competition': '165'}
# {'jobId': '153629628', 'jobName': '开发工程师（应届生岗位）', 'jobAreaString': '上海', 'provideSalaryString': '1-1.5万·16薪', 'issueDateString': '2024-04-03 09:47:02', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '安吉租赁有限公司', 'companyTypeString': '国企', 'companySizeString': '150-500人', 'jobHref': 'https://jobs.51job.com/shanghai/153629628.html?s=sou_sou_soulb&t=0_0&req=ed79fc9fed2a62bae4368a66bf6224a6', 'termStr': '全职', 'jobWelfareCodeDataList': [], 'monthly_salary': 16666.67, 'competition': '1213'}
# {'jobId': '150917446', 'jobName': '2024年应届生-软件开发助理工程师', 'jobAreaString': '上海', 'provideSalaryString': '15-28万/年', 'issueDateString': '2024-03-29 04:00:40', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '国核自仪系统工程有限公司', 'companyTypeString': '国企', 'companySizeString': '150-500人', 'jobHref': 'https://jobs.51job.com/shanghai-mhq/150917446.html?s=sou_sou_soulb&t=0_0&req=ed79fc9fed2a62bae4368a66bf6224a6', 'termStr': '全职', 'jobWelfareCodeDataList': ['免费班车', '餐饮补贴', '五险一金', '交通补贴', '补充公积金', '补充医疗保险', '定期体检', '周末双休', '绩效奖金'], 'monthly_salary': 17916.67, 'competition': '617'}
# {'jobId': '131495080', 'jobName': '解决方案助理（应届毕业生亦可）', 'jobAreaString': '广州', 'provideSalaryString': '4.5-6千', 'issueDateString': '2024-04-02 15:32:39', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '广州云鑫为信息科技有限公司', 'companyTypeString': '民营', 'companySizeString': '50-150人', 'jobHref': 'https://jobs.51job.com/guangzhou-thq/131495080.html?s=sou_sou_soulb&t=0_0&req=8b73fe32e4111d8bba93d0eca40d2db5', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '周末双休', '通讯补贴', '绩效奖金', '交通补贴', '补充医疗保险', '员工旅游', '定期体检', '专业培训', '股票期权'], 'monthly_salary': 5250.0, 'competition': '30'}
# {'jobId': '154023299', 'jobName': '芯片应用/测试工程师（接受应届毕业）', 'jobAreaString': '上海', 'provideSalaryString': '1.5-2.5万·15薪', 'issueDateString': '2024-04-03 10:34:15', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '意瑞半导体（上海）有限公司', 'companyTypeString': '民营', 'companySizeString': '50-150人', 'jobHref': 'https://jobs.51job.com/shanghai-mhq/154023299.html?s=sou_sou_soulb&t=0_0&req=4c8f6c7c9b6489bd808250754df003c4', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '交通补贴', '绩效奖金'], 'monthly_salary': 25000.0, 'competition': '185'}
# {'jobId': '152178802', 'jobName': '技术工程师（应届岗）', 'jobAreaString': '上海', 'provideSalaryString': '7千-1.2万·13薪', 'issueDateString': '2024-03-11 10:27:54', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '上海万澄环保科技有限公司', 'companyTypeString': '民营', 'companySizeString': '50-150人', 'jobHref': 'https://jobs.51job.com/shanghai-pdxq/152178802.html?s=sou_sou_soulb&t=0_0&req=b67a4984c5bfc8711e91a96043e6515e', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '员工旅游', '专业培训', '绩效奖金', '定期体检', '年终奖金'], 'monthly_salary': 10291.67, 'competition': '89'}
# {'jobId': '141357619', 'jobName': '软件工程师-应届毕业生', 'jobAreaString': '深圳', 'provideSalaryString': '7千-1万', 'issueDateString': '2024-04-02 11:31:07', 'workYearString': '1年', 'degreeString': '本科', 'fullCompanyName': '深圳市巨潮科技股份有限公司', 'companyTypeString': '民营', 'companySizeString': '50-150人', 'jobHref': 'https://jobs.51job.com/shenzhen/141357619.html?s=sou_sou_soulb&t=0_0&req=4adfe8bd351b80b7f2ee0b6da4c06792', 'termStr': '全职', 'jobWelfareCodeDataList': ['周末双休', '带薪年假', '五险一金', '节日福利', '交通补贴', '餐饮补贴', '定期体检'], 'monthly_salary': 8500.0, 'competition': '1095'}
# {'jobId': '152031131', 'jobName': '2024应届生-（计算机/信息技术专业）', 'jobAreaString': '北京', 'provideSalaryString': '9千-1.1万', 'issueDateString': '2024-03-25 10:04:38', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '延锋海纳川汽车饰件系统有限公司', 'companyTypeString': '国企', 'companySizeString': '1000-5000人', 'jobHref': 'https://jobs.51job.com/beijing-syq/152031131.html?s=sou_sou_soulb&t=0_0&req=91d9b9529795be1be2906508142120b4', 'termStr': '全职', 'jobWelfareCodeDataList': ['补充医疗保险', '周末双休', '定期体检', '交通补贴', '年终奖金', '五险一金', '工作餐', '带薪年假'], 'monthly_salary': 10000.0, 'competition': '176'}
# {'jobId': '150305634', 'jobName': 'Bios软件开发工程师（应届生）', 'jobAreaString': '深圳', 'provideSalaryString': '8千-1万', 'issueDateString': '2024-03-29 08:34:18', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '深圳市杰和科技发展有限公司', 'companyTypeString': '民营', 'companySizeString': '150-500人', 'jobHref': 'https://jobs.51job.com/shenzhen-nsq/150305634.html?s=sou_sou_soulb&t=0_0&req=678c631c436811a93c9712791e3c9d4a', 'termStr': '全职', 'jobWelfareCodeDataList': ['周末双休', '带薪年假', '五险一金', '绩效奖金', '节日福利', '专业培训', '年终奖金'], 'monthly_salary': 9000.0, 'competition': '112'}
# {'jobId': '154156521', 'jobName': 'Android驱动（助理）工程师（2024年应届毕业生）', 'jobAreaString': '深圳', 'provideSalaryString': '7-8千', 'issueDateString': '2024-04-06 04:00:34', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '湖南晶讯光电股份有限公司', 'companyTypeString': '民营', 'companySizeString': '1000-5000人', 'jobHref': 'https://jobs.51job.com/shenzhen-baq/154156521.html?s=sou_sou_soulb&t=0_0&req=d353de0d56bd4fba5e176d7d453705f2', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '包住宿', '免费班车', '餐饮补贴'], 'monthly_salary': 7500.0, 'competition': '33'}
# {'jobId': '152922642', 'jobName': '软件工程师（应届生）', 'jobAreaString': '深圳', 'provideSalaryString': '1-2万·14薪', 'issueDateString': '2024-04-02 15:39:47', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '上海品峰医疗科技有限公司', 'companyTypeString': '合资', 'companySizeString': '150-500人', 'jobHref': 'https://jobs.51job.com/shenzhen-gmq/152922642.html?s=sou_sou_soulb&t=0_0&req=102c114c154c836272f9ccfb42bbfcdc', 'termStr': '全职', 'jobWelfareCodeDataList': [], 'monthly_salary': 17500.0, 'competition': '1159'}
# {'jobId': '150893958', 'jobName': '芯片项目经理/PM（应届生）', 'jobAreaString': '上海', 'provideSalaryString': '8千-1.5万·14薪', 'issueDateString': '2024-04-05 21:29:10', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '苇创微电子（上海）有限公司', 'companyTypeString': '民营', 'companySizeString': '50-150人', 'jobHref': 'https://jobs.51job.com/shanghai-pdxq/150893958.html?s=sou_sou_soulb&t=0_0&req=834b33dfb7a0f90396b0106ce5b15f12', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '交通补贴', '餐饮补贴', '定期体检'], 'monthly_salary': 13416.67, 'competition': '85'}
# {'jobId': '150236877', 'jobName': '销售技术工程师（应届生）', 'jobAreaString': '上海', 'provideSalaryString': '7-8千', 'issueDateString': '2024-04-03 09:21:08', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '上海贤达美尔森过程设备有限公司', 'companyTypeString': '外资（欧美）', 'companySizeString': '150-500人', 'jobHref': 'https://jobs.51job.com/shanghai-fxq/150236877.html?s=sou_sou_soulb&t=0_0&req=d1ae589fbf15ba4f2aa34253a7a85d43', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '免费班车', '周末双休', '专业培训', '补充医疗保险', '交通补贴', '定期体检', '带薪年假', '节日福利', '通讯补贴'], 'monthly_salary': 7500.0, 'competition': '30'}
# {'jobId': '153493451', 'jobName': 'JAVA 开发工程师（应届生）', 'jobAreaString': '广州', 'provideSalaryString': '6-7千', 'issueDateString': '2024-03-19 10:31:20', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '北京美络克思科技有限公司', 'companyTypeString': '民营', 'companySizeString': '150-500人', 'jobHref': 'https://jobs.51job.com/guangzhou-yxq/153493451.html?s=sou_sou_soulb&t=0_0&req=0a1a2a68935239f969658f55cda56062', 'termStr': '全职', 'jobWelfareCodeDataList': ['周末双休', '带薪年假'], 'monthly_salary': 6500.0, 'competition': '1991'}

# %%
for i in range(1,7):
    for job in data[f'random_part_{i}']:
        if '在校生/应届生' not in job['workYearString']:
            if "可招" in job['jobName'] or "接受" in job['jobName'] or "亦可" in job['jobName']:
                print(job)
# Out:
# {'jobId': '131220715', 'jobName': '部门助理（双休、可招应届生）', 'jobAreaString': '深圳', 'provideSalaryString': '5-8千', 'issueDateString': '2024-04-01 11:52:39', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '昭星实业（深圳）有限公司', 'companyTypeString': '民营', 'companySizeString': '50-150人', 'jobHref': 'https://jobs.51job.com/shenzhen-gmq/131220715.html?s=sou_sou_soulb&t=0_0&req=a51d7c6820bef931b2a9ff141c8df2d8', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '员工旅游', '绩效奖金', '节日福利', '带薪年假', '周末双休', '全勤奖', '餐饮补贴'], 'monthly_salary': 6500.0, 'competition': '181'}
# {'jobId': '40623618', 'jobName': 'PHP软件开发工程师（应届生亦可）', 'jobAreaString': '上海', 'provideSalaryString': '8千-1万', 'issueDateString': '2024-04-05 11:25:36', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '亿泰和信息技术（上海）有限公司', 'companyTypeString': '外资（欧美）', 'companySizeString': '50-150人', 'jobHref': 'https://jobs.51job.com/shanghai-ptq/40623618.html?s=sou_sou_soulb&t=0_0&req=5020d73e3772c10c0e47b47c470917eb', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '餐饮补贴', '年终奖金', '专业培训'], 'monthly_salary': 9000.0, 'competition': '165'}
# {'jobId': '131495080', 'jobName': '解决方案助理（应届毕业生亦可）', 'jobAreaString': '广州', 'provideSalaryString': '4.5-6千', 'issueDateString': '2024-04-02 15:32:39', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '广州云鑫为信息科技有限公司', 'companyTypeString': '民营', 'companySizeString': '50-150人', 'jobHref': 'https://jobs.51job.com/guangzhou-thq/131495080.html?s=sou_sou_soulb&t=0_0&req=8b73fe32e4111d8bba93d0eca40d2db5', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '周末双休', '通讯补贴', '绩效奖金', '交通补贴', '补充医疗保险', '员工旅游', '定期体检', '专业培训', '股票期权'], 'monthly_salary': 5250.0, 'competition': '30'}
# {'jobId': '154023299', 'jobName': '芯片应用/测试工程师（接受应届毕业）', 'jobAreaString': '上海', 'provideSalaryString': '1.5-2.5万·15薪', 'issueDateString': '2024-04-03 10:34:15', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '意瑞半导体（上海）有限公司', 'companyTypeString': '民营', 'companySizeString': '50-150人', 'jobHref': 'https://jobs.51job.com/shanghai-mhq/154023299.html?s=sou_sou_soulb&t=0_0&req=4c8f6c7c9b6489bd808250754df003c4', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '交通补贴', '绩效奖金'], 'monthly_salary': 25000.0, 'competition': '185'}
# {'jobId': '153501378', 'jobName': 'ABAP开发工程师（可接受free）', 'jobAreaString': '北京', 'provideSalaryString': '1-2万', 'issueDateString': '2024-04-01 15:18:55', 'workYearString': '2年及以上', 'degreeString': '本科', 'fullCompanyName': '深圳薪安易网络科技有限公司', 'companyTypeString': '民营', 'companySizeString': '少于50人', 'jobHref': 'https://jobs.51job.com/beijing-cpq/153501378.html?s=sou_sou_soulb&t=0_0&req=909cc6d5dea4631fae5e4ddf9cebe2cc', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '绩效奖金'], 'monthly_salary': 15000.0, 'competition': '20'}

# %%
# 调用函数进行数据清洗
data=clean_data_jobName(data)

# %%
# 设定起始日期
start_date_str = '2024-4-7'
start_date = datetime.strptime(start_date_str, '%Y-%m-%d')



company_jobs = {}
for job in data:

    job["jobAreaString"] = job["jobAreaString"].split('·')[0]

    if job["jobAreaString"] in ["北京","上海","广州","深圳"]:

        # 将 issue_date 从字符串转换为 datetime 对象

        issue_date = datetime.strptime(job["issueDateString"], "%Y-%m-%d %H:%M:%S")

        # 计算 issue_date 和 start_date 之间的差异
        date_diff = (start_date - issue_date).days

        monthly_salary = calculate_monthly_salary(job["provideSalaryString"])
        if monthly_salary is not None:
            job["monthly_salary"] = monthly_salary
        else:
            job["monthly_salary"] = -1


        if date_diff <= 30 and (job["monthly_salary"]<40000 ):

            if job["fullCompanyName"] in company_jobs:
                company_jobs[job["fullCompanyName"]].append(job)
            else:
                company_jobs[job["fullCompanyName"]] = [job]

# 随机选择一个职位项
randomized_data = [random.choice(jobs) for jobs in company_jobs.values()]

# 输出处理后的数据以确认
#print(json.dumps(randomized_data, ensure_ascii=False, indent=4))


# 将处理后的数据保存到新的 JSON 文件中
with open(output_file, 'w', encoding='utf-8') as new_file:
    json.dump(randomized_data, new_file, ensure_ascii=False, indent=4)

# %%
# 处理后的数据再随机分割为6份
random_split_json_array(output_file)
