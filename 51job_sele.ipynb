# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.service import Service
from time import sleep
import json

import json
from time import sleep

from selenium import webdriver
from selenium.webdriver.chrome.options import Options as ChromeOptions
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.service import Service
import json
import datetime
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.service import Service
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException
import random

import re

# %%
def read_json_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data





def get_competition(text):
    # 假设你已经用之前的方法获得了这个字符串,字符串样例示例：
    #text = "（排名129/364）"
    # 使用正则表达式匹配文本中的数字
    matches = re.findall(r'\d+', text)

    # 假设文本格式固定，排名和总人数都是数字，并且总人数在第二个位置
    if matches:
        total_number = matches[1]  # 获取总人数
        
    return total_number



def transform_salary_description(salary_desc):
    # 检查是否包含"及以下"，以及是千还是万
    if '千及以下' in salary_desc:
        value, _ = salary_desc.split('千及以下')
        min_value = round(float(value) * 0.6, 5)  # 计算下限并四舍五入到5位小数
        new_salary_desc = f"{min_value}-{value}千"
    elif '万及以下' in salary_desc:
        value, _ = salary_desc.split('万及以下')
        min_value = round(float(value) * 0.6, 5)  # 计算下限并四舍五入到5位小数
        new_salary_desc = f"{min_value}-{value}万"
    else:
        # 如果不符合上述任一条件，则不需要转换
        return salary_desc
    
    return new_salary_desc




def parse_and_average_salary(salary):
    # 将薪资字符串中的“千”和“万”统一转换为浮点数（以“万”为单位）
    salary = salary.replace('千', '*0.1').replace('万', '')
    # 分割薪资范围
    salary_range = salary.split('-')
    # 计算薪资范围的平均值
    if len(salary_range) == 2:
        min_salary, max_salary = salary_range
        average_salary = ((eval(min_salary) + eval(max_salary)) * 10000) / 2
    else:
        average_salary = eval(salary_range[0]) * 10000
    return round(average_salary , 2)  # 返回平均薪资，单位为元


def parse_and_average_salary_true(salary):
    # 将薪资字符串中的“千”和“万”统一转换为浮点数（以“万”为单位）
    if "万" in salary:
        salary = salary.replace('千', '*0.1').replace('万', '')
        # 分割薪资范围
        salary_range = salary.split('-')
        # 计算薪资范围的平均值
        if len(salary_range) == 2:
            min_salary, max_salary = salary_range
            average_salary = ((eval(min_salary) + eval(max_salary)) * 10000) / 2
        else:
            average_salary = eval(salary_range[0]) * 10000
        return round(average_salary , 2)  # 返回平均薪资，单位为元
    #仅含"千"
    else:
        salary = salary.replace('千', '')
        salary_range = salary.split('-')
        if len(salary_range) == 2:
            min_salary, max_salary = salary_range
            average_salary = ((eval(min_salary) + eval(max_salary)) * 1000) / 2
        else:
            average_salary = eval(salary_range[0]) * 1000
        return round(average_salary , 2)  # 返回平均薪资，单位为元



def calculate_monthly_salary_true(salary_string):
    # 假设transform_salary_description已经将薪资描述转换为了易于解析的格式
    salary_string=transform_salary_description(salary_string)
    if '年' in salary_string:
        salary_string = salary_string.replace('/年', '')
        average_annual_salary = parse_and_average_salary_true(salary_string)
        return round(average_annual_salary / 12, 2)  # 转换为月薪
    elif '薪' in salary_string:
        salary_range, months = salary_string.split('·')
        average_salary = parse_and_average_salary_true(salary_range)
        months = float(months.replace('薪', ''))
        return round(average_salary * months / 12, 2)  # 计算年薪再转换为月薪
    elif '-' in salary_string:
        return parse_and_average_salary_true(salary_string)  # 直接返回月薪
    else:
        # 不属于上述情况，可能需要进一步处理
        return None



def calculate_monthly_salary(salary_string):
    # 假设transform_salary_description已经将薪资描述转换为了易于解析的格式
    salary_string=transform_salary_description(salary_string)
    if '年' in salary_string:
        salary_string = salary_string.replace('/年', '')
        average_annual_salary = parse_and_average_salary(salary_string)
        return round(average_annual_salary / 12, 2)  # 转换为月薪
    elif '薪' in salary_string:
        salary_range, months = salary_string.split('·')
        average_salary = parse_and_average_salary(salary_range)
        months = float(months.replace('薪', ''))
        return round(average_salary * months / 12, 2)  # 计算年薪再转换为月薪
    elif '-' in salary_string:
        return parse_and_average_salary(salary_string)  # 直接返回月薪
    else:
        # 不属于上述情况，可能需要进一步处理
        return None




# 定义一个函数来读取 JSON 文件
def read_json_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
    return data

# %%
options = ChromeOptions()
""" #使用代理服务器，便于用Mitmproxy监听
options.add_argument("--proxy-server=http://localhost:8080") """
# 忽略SSL错误
options.add_argument("--ignore-ssl-errors=yes")
options.add_argument("--ignore-certificate-errors")
#禁用Blink引擎的某些特性，未指定
options.add_argument("--disable-blink-features")
#隐藏Selenium自动化控制的痕迹
options.add_argument("--disable-blink-features=AutomationControlled")

############
#无界面模式
#options.add_argument("--headless")
############

chromedriver_path = r"C:\chromedriver-win64\chromedriver.exe"


""" try:
    times = int(input("输入需要爬取的数量，没有输入则爬取所有岗位"))
except ValueError:
    times = float('inf')  # 设置为无限大，表示爬取所有职位
 """
times = float('inf')

# 创建Service对象，并传入ChromeDriver的路径
service = Service(executable_path=chromedriver_path)
# 使用Service对象初始化Chrome WebDriver
driver = webdriver.Chrome(service=service,options=options)

wait = WebDriverWait(driver, 60)

# %%
test_url=f"https://i.51job.com/userset/compete.php?jobid=154254982&resumeid=468287804&accountid=241451461&lang=c"

driver.get(test_url)

# %%
element_text = driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[2]/div[1]/strong[2]').text

print(element_text)
# Out:
# （排名135/386）

# %%
data=read_json_file(r"C:\Users\Xue\Documents\GitHub\gender-discrimination-hiring\added.json")

# %%
import os
import json

# 指定文件夹路径
folder_path = 'C:\\Users\\Xue\\Documents\\GitHub\\gender-discrimination-hiring\\修正'
# 初始化一个空字典来存储加载的JSON数据
data = {}

# 遍历文件夹中的所有文件
for filename in os.listdir(folder_path):
    # 检查文件是否为JSON文件
    if filename.endswith('.json'):
        # 构建完整的文件路径
        file_path = os.path.join(folder_path, filename)
        # 加载JSON数据
        with open(file_path, 'r', encoding='utf-8') as file:
            data[filename[:-5]] = json.load(file)

# 现在，`data`字典包含了所有JSON文件的数据，键是文件名（不包括扩展名）

# %%
for i in range(1,7):
    for job in data[f'random_part_{i}']:
        if "在校生/应届生" in job['workYearString']:
            job['competition']="在校生/应届生数据，忽略抓取"
        else:
            if "competition" in job:
                continue
            else:
                competition_url=f"https://i.51job.com/userset/compete.php?jobid={job["jobId"]}&resumeid=468287804&accountid=241451461&lang=c"

                driver.get(competition_url)

                #加一个等待加载的
                sleep_time=random.uniform(1.5,2.5)
                sleep(sleep_time)
                try:
                    element_text = driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[2]/div[1]/strong[2]').text
                    competition=get_competition(element_text)
                    job['competition']=competition
                except NoSuchElementException:
                    job['competition']='无competition数据'
                    print(job)
                except:
                    sleep_time=random.uniform(1.5,2.5)
                    sleep(sleep_time) 
                    element_text = driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[2]/div[1]/strong[2]').text
                    competition=get_competition(element_text)
                    job['competition']=competition             


    # 将处理后的数据保存到新的 JSON 文件中
    with open(file_path+'_competition.json', 'w', encoding='utf-8') as new_file:
        json.dump(data, new_file, ensure_ascii=False, indent=4)
# Out:
# {'jobId': '141001325', 'jobName': 'GIS开发工程师', 'jobAreaString': '北京', 'provideSalaryString': '1.1-2万', 'issueDateString': '2024-04-06 04:00:50', 'workYearString': '3-4年', 'degreeString': '本科', 'fullCompanyName': '东华软件智能科技有限公司', 'companyTypeString': '民营', 'companySizeString': '', 'jobHref': 'https://jobs.51job.com/beijing/141001325.html?s=sou_sou_soulb&t=0_0&req=d142226751e3e2dc4a3fe1c8075fb7a6', 'termStr': '全职', 'jobWelfareCodeDataList': [], 'monthly_salary': 15500.0}
# {'jobId': '142112705', 'jobName': 'Java开发工程师', 'jobAreaString': '广州', 'provideSalaryString': '8千-1.2万', 'issueDateString': '2024-04-06 05:14:37', 'workYearString': '2年', 'degreeString': '本科', 'fullCompanyName': '广州极点三维信息科技有限公司', 'companyTypeString': '民营', 'companySizeString': '', 'jobHref': 'https://jobs.51job.com/guangzhou/142112705.html?s=sou_sou_soulb&t=0_0&req=0a1a2a68935239f969658f55cda56062', 'termStr': '全职', 'jobWelfareCodeDataList': [], 'monthly_salary': 10000.0}
# ...

# %%
data=read_json_file(r'C:\Users\Xue\Documents\GitHub\gender-discrimination-hiring\修正\data_part_6.json')

for i in range(1,7):
    for job in data[f'random_part_{i}']:

        monthly_salary = calculate_monthly_salary_true(job["provideSalaryString"])
        if monthly_salary is not None:
            job["monthly_salary"] = monthly_salary
        else:
            job["monthly_salary"] = -1


# 将处理后的数据保存到新的 JSON 文件中
with open(r'修正/data_part_all.json', 'w', encoding='utf-8') as new_file:
    json.dump(data, new_file, ensure_ascii=False, indent=4)

# %%
for i in range(1,7):

    with open(f'修正/data_part_all_{i}.json', 'w', encoding='utf-8') as new_file:
        json.dump(data[f'random_part_{i}'], new_file, ensure_ascii=False, indent=4)

# %%
import json
import random
from time import sleep
from selenium.common.exceptions import NoSuchElementException
# 假设 driver 和 get_competition 函数已经正确设置

# 定义保存数据的函数
def save_data(data, file_path):
    with open(file_path, 'w', encoding='utf-8') as file:
        json.dump(data, file, ensure_ascii=False, indent=4)

for i in range(1, 7):
    for job in data[f'random_part_{i}']:
        if "在校生/应届生" in job['workYearString']:
            job['competition'] = "在校生/应届生数据，忽略抓取"
            save_data(data, f"修正/data_part_{i}.json")  # 立即保存数据
        else:
            if "competition" not in job:
                competition_url = f"https://i.51job.com/userset/compete.php?jobid={job['jobId']}&resumeid=468287804&accountid=241451461&lang=c"
                driver.get(competition_url)
                sleep_time = random.uniform(1.5, 2.5)
                sleep(sleep_time)
                try:
                    element_text = driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[2]/div[1]/strong[2]').text
                    competition = get_competition(element_text)
                    job['competition'] = competition
                    save_data(data, f"修正/data_part_{i}.json")  # 立即保存数据
                except NoSuchElementException:
                    job['competition']='无competition数据'
                    print(job)
                except Exception as e:
                    sleep_time = random.uniform(1.5, 2.5)
                    sleep(sleep_time)
                    element_text = driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[2]/div[1]/strong[2]').text
                    competition = get_competition(element_text)
                    job['competition'] = competition
                    save_data(data, f"修正/data_part_{i}.json")  # 立即保存数据
# Out:
# {'jobId': '141001325', 'jobName': 'GIS开发工程师', 'jobAreaString': '北京', 'provideSalaryString': '1.1-2万', 'issueDateString': '2024-04-06 04:00:50', 'workYearString': '3-4年', 'degreeString': '本科', 'fullCompanyName': '东华软件智能科技有限公司', 'companyTypeString': '民营', 'companySizeString': '', 'jobHref': 'https://jobs.51job.com/beijing/141001325.html?s=sou_sou_soulb&t=0_0&req=d142226751e3e2dc4a3fe1c8075fb7a6', 'termStr': '全职', 'jobWelfareCodeDataList': [], 'monthly_salary': 15500.0}
# {'jobId': '142112705', 'jobName': 'Java开发工程师', 'jobAreaString': '广州', 'provideSalaryString': '8千-1.2万', 'issueDateString': '2024-04-06 05:14:37', 'workYearString': '2年', 'degreeString': '本科', 'fullCompanyName': '广州极点三维信息科技有限公司', 'companyTypeString': '民营', 'companySizeString': '', 'jobHref': 'https://jobs.51job.com/guangzhou/142112705.html?s=sou_sou_soulb&t=0_0&req=0a1a2a68935239f969658f55cda56062', 'termStr': '全职', 'jobWelfareCodeDataList': [], 'monthly_salary': 10000.0}
# ...

# %%
merge=r"C:\Users\Xue\OneDrive\0_Code\data\2024-4-6-1800-2000\merge.json"

final_data=r"C:\Users\Xue\OneDrive\0_Code\data\final_processed_jobs_or.json"

# %%
{'jobId': '141001325', 'jobName': 'GIS开发工程师', 'jobAreaString': '北京', 'provideSalaryString': '1.1-2万', 'issueDateString': '2024-04-06 04:00:50', 'workYearString': '3-4年', 'degreeString': '本科', 'fullCompanyName': '东华软件智能科技有限公司', 'companyTypeString': '民营', 'companySizeString': '', 'jobHref': 'https://jobs.51job.com/beijing/141001325.html?s=sou_sou_soulb&t=0_0&req=d142226751e3e2dc4a3fe1c8075fb7a6', 'termStr': '全职', 'jobWelfareCodeDataList': [], 'monthly_salary': 15500.0}
{'jobId': '142112705', 'jobName': 'Java开发工程师', 'jobAreaString': '广州', 'provideSalaryString': '8千-1.2万', 'issueDateString': '2024-04-06 05:14:37', 'workYearString': '2年', 'degreeString': '本科', 'fullCompanyName': '广州极点三维信息科技有限公司', 'companyTypeString': '民营', 'companySizeString': '', 'jobHref': 'https://jobs.51job.com/guangzhou/142112705.html?s=sou_sou_soulb&t=0_0&req=0a1a2a68935239f969658f55cda56062', 'termStr': '全职', 'jobWelfareCodeDataList': [], 'monthly_salary': 10000.0}
{'jobId': '154199234', 'jobName': '网络工程师', 'jobAreaString': '深圳', 'provideSalaryString': '1-1.5万', 'issueDateString': '2024-04-06 04:00:34', 'workYearString': '3-4年', 'degreeString': '本科', 'fullCompanyName': '深圳蔚云科技有限公司', 'companyTypeString': '民营', 'companySizeString': '', 'jobHref': 'https://jobs.51job.com/shenzhen-lgq/154199234.html?s=sou_sou_soulb&t=0_0&req=36503fd04d048922df207d42778bed6e', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '双休'], 'monthly_salary': 12500.0}
{'jobId': '147283871', 'jobName': '嵌入式软件工程师', 'jobAreaString': '北京', 'provideSalaryString': '8千-1.3万', 'issueDateString': '2024-04-06 04:00:34', 'workYearString': '3-4年', 'degreeString': '本科', 'fullCompanyName': '北京力天世技系统集成有限公司', 'companyTypeString': '民营', 'companySizeString': '', 'jobHref': 'https://jobs.51job.com/beijing-cyq/147283871.html?s=sou_sou_soulb&t=0_0&req=4db05db183aa07dc79a98c4a7066b345', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '弹性工作', '定期团建', '下午茶'], 'monthly_salary': 10500.0}
{'jobId': '140337170', 'jobName': '前端研发工程师', 'jobAreaString': '广州', 'provideSalaryString': '1.4-1.5万', 'issueDateString': '2024-04-06 05:13:49', 'workYearString': '5-7年', 'degreeString': '本科', 'fullCompanyName': '广州金域医学检验中心有限公司', 'companyTypeString': '民营', 'companySizeString': '', 'jobHref': 'https://jobs.51job.com/guangzhou/140337170.html?s=sou_sou_soulb&t=0_0&req=3b056c1454713d84e33b88c07e950538', 'termStr': '全职', 'jobWelfareCodeDataList': [], 'monthly_salary': 14500.0}
{'jobId': '147193117', 'jobName': '项目助理', 'jobAreaString': '北京', 'provideSalaryString': '7千-1万', 'issueDateString': '2024-04-06 04:00:34', 'workYearString': '2年', 'degreeString': '本科', 'fullCompanyName': '凯泰铭科技（北京）有限公司', 'companyTypeString': '民营', 'companySizeString': '', 'jobHref': 'https://jobs.51job.com/beijing/147193117.html?s=sou_sou_soulb&t=0_0&req=f0bda063b0f55cf9220331b6bc0d7316', 'termStr': '全职', 'jobWelfareCodeDataList': [], 'monthly_salary': 8500.0}
{'jobId': '153593626', 'jobName': '产品交付与售后岗位', 'jobAreaString': '北京', 'provideSalaryString': '1-2万', 'issueDateString': '2024-03-09 04:00:40', 'workYearString': '3-4年', 'degreeString': '本科', 'fullCompanyName': '首都机场集团科技管理有限公司', 'companyTypeString': '国企', 'companySizeString': '', 'jobHref': 'https://jobs.51job.com/beijing-syq/153593626.html?s=sou_sou_soulb&t=0_0&req=151a3a896b83917b84d220429441aea7', 'termStr': '全职', 'jobWelfareCodeDataList': [], 'monthly_salary': 15000.0}
{'jobId': '150568298', 'jobName': '新能源装备软件开发工程师', 'jobAreaString': '广州', 'provideSalaryString': '9千-1.2万', 'issueDateString': '2024-03-19 04:00:35', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '中国电器科学研究院股份有限公司', 'companyTypeString': '国企', 'companySizeString': '', 'jobHref': 'https://jobs.51job.com/guangzhou/150568298.html?s=sou_sou_soulb&t=0_0&req=6e7cd605e2b9cd61d3057aa0101a7252', 'termStr': '全职', 'jobWelfareCodeDataList': [], 'monthly_salary': 10500.0}
{'jobId': '147184601', 'jobName': '应用工程师', 'jobAreaString': '北京', 'provideSalaryString': '6-9千·13薪', 'issueDateString': '2024-04-06 04:00:34', 'workYearString': '无需经验', 'degreeString': '本科', 'fullCompanyName': '广州宝力机械科技有限公司北京分公司', 'companyTypeString': '外资（非欧美）', 'companySizeString': '', 'jobHref': 'https://jobs.51job.com/beijing/147184601.html?s=sou_sou_soulb&t=0_0&req=151a3a896b83917b84d220429441aea7', 'termStr': '全职', 'jobWelfareCodeDataList': ['五险一金', '补充医疗保险', '通讯补贴', '年终奖金', '员工旅游', '出国机会', '交通补贴', '专业培训'], 'monthly_salary': 37375.0}

# %%
data2=read_json_file(merge)
https://i.51job.com/userset/compete.php?jobid=85858654&resumeid=468287804&accountid=241451461&lang=c

https://i.51job.com/userset/compete.php?jobid=153229333&resumeid=468287804&accountid=241451461&lang=c

# %%
data3=read_json_file(final_data)

# %%
jobIds=[]
for job in data3:
    jobIds.append(job["jobId"])
jobHerfs=set()
InSchool_jobIds=set()

i=0
for job in data2:
    if job["jobId"] in jobIds:
        if "在校生/应届生" in job["workYearString"]:
            print(job["jobHref"])
            InSchool_jobIds.add(job["jobId"])
            i=i+1
print(i)
j=0
for job in InSchool_jobIds:
    j=j+1
print(j)

# %%
data3=read_json_file(r'C:\Users\Xue\Documents\GitHub\gender-discrimination-hiring\修正\random_part_1.json')
data4= read_json_file(r'C:\Users\Xue\Documents\GitHub\gender-discrimination-hiring\修正\random_part_2.json')
data5=read_json_file(r'C:\Users\Xue\Documents\GitHub\gender-discrimination-hiring\修正\random_part_3.json')
data6=read_json_file(r'C:\Users\Xue\Documents\GitHub\gender-discrimination-hiring\修正\random_part_4.json')
data7=read_json_file(r'C:\Users\Xue\Documents\GitHub\gender-discrimination-hiring\修正\random_part_5.json')
data8=read_json_file(r'C:\Users\Xue\Documents\GitHub\gender-discrimination-hiring\修正\random_part_6.json')

# %%
jobIds=[]

jobHerfs=set()
InSchool_jobIds=[]



for job in data8:
    jobIds.append(job["jobId"])

i=0
for job in data2:
    if job["jobId"] in jobIds:
        if "在校生/应届生" in job["workYearString"]:
            InSchool_jobIds.append(job["jobId"])

for job in data8:
    if job["jobId"] in InSchool_jobIds:
        job["workYearString"]="在校生/应届生"
    else :
        job["workYearString"]=""

    monthly_salary = calculate_monthly_salary_true(job["provideSalaryString"])
    if monthly_salary is not None:
        job["monthly_salary"] = monthly_salary
    else:
        job["monthly_salary"] = -1


# 将处理后的数据保存到新的 JSON 文件中
with open(r'修正\random_part_6_workyear.json', 'w', encoding='utf-8') as new_file:
    json.dump(data3, new_file, ensure_ascii=False, indent=4)



            # print(job["jobHref"])
            
            # jobHerfs.add(job["jobHref"])
            # i=i+1


# print(i)
# j=0
# for job in jobHerfs:
#     j=j+1
# print(j)

# %%
for job in data:
   if competition not in job:
      print(job)
# Out:
# {'jobId': '151227315', 'jobName': '系统与软件建模工程师', 'jobAreaString': '北京', 'provideSalaryString': '7-9千·14薪', 'issueDateString': '2024-04-04 16:44:16', 'workYearString': '1年', 'degreeString': '本科', 'fullCompanyName': '北京火龙果网络技术有限公司', 'companyTypeString': '民营', 'companySizeString': '少于50人', 'jobHref': 'https://jobs.51job.com/beijing-hdq/151227315.html?s=sou_sou_soulb&t=0_0&req=3738bc51edb5e11634a60dda48212b68', 'termStr': '全职', 'jobWelfareCodeDataList': ['节日福利', '交通补贴', '餐饮补贴', '生日福利', '公司旅游', '专业培训', '通讯补贴', '五险一金'], 'monthly_salary': 46083.33, 'monthly_salary_true': 9333.33, 'competition': '11'}
# ...

# %%
test_url=f"https://i.51job.com/userset/compete.php?jobid=154254982&resumeid=468287804&accountid=241451461&lang=c"

driver.get(test_url)

#拿取jobId的



#加一个等待加载的
sleep_time=random.uniform(0.5,2.0)
sleep(sleep_time)

#抓取，保存

element_text = driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[2]/div[1]/strong[2]').text

print(element_text)
